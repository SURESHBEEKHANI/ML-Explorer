# %% [markdown]
# <a href="https://colab.research.google.com/github/SURESHBEEKHANI/SURESH_Beekhani_Machine_Learning_Projects-with-source-code/blob/main/Simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import matplotlib .pyplot as plt
import pandas as pd
import numpy as np

# %%
#Read data set
data=pd.read_csv("/content/placement (1).csv")

# %%
data.head(5)

# %%
#plot data in Graph
plt.scatter(data['cgpa'],data['package'])
plt.xlabel('cgpa')
plt.ylabel('package')

# %%
x=data.iloc[:,0:1]
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# Assuming x_train and x_test are the input features for training and testing, respectively
# and y_train and y_test are the corresponding target values.

# Create a LinearRegression object
lr = LinearRegression()

# Fit the model on the training data
lr.fit(x_train, y_train)

# %%
x_test

# %%
y_test

# %%
plt.scatter(data['cgpa'],data['package'])

# Add labels and a title
plt.xlabel('CGPA')
plt.ylabel('Pakage (in lpa )')
plt.plot(x_train,lr.predict(x_train),color='red')
plt.title('linear Regression CGPA b/w Package')

# Show a legend (if you have multiple datasets to distinguish)
plt.legend()

# Display the plot
plt.show()
